# %% [markdown]
# # GLANSIS - PDF Keyword Extractor
# Following script will pull keywords from PDFs. Keywords will be cleaned and scientific and comman names will be added before being added to Endnote Excel sheet for bulk upload.

# %% [markdown]
# ### Upload Libraries

# %%
# DO NOT EDIT
import fitz                  # open and pdf manipulation - package for PyMuPDF
import os                    # change working directory
import pandas as pd          # df manipulation
from datetime import date    # extract date for csv title output
import unicodedata           # convert extracted keywords to unicode - removes issues with duplication

# %% [markdown]
# ### Add in local information:
# - pdfs_folder_path: directory of PDFs on local drive
# - setwd: location where excel is kept and location for output excel
# - ref_sheet: name of reference sheet
# - names: scientific and common names

# %%
# Set folder paths for PDFs
pdfs_folder_path = r'C:/Users/redinger/Documents/GLANSIS_folder/Endnote_species/Nitellopsis obtusa/pdfs'

# Set working directory
setwd = r'C:/Users/redinger/Documents/GLANSIS_folder/Endnote_species/Nitellopsis obtusa'

# Name of reference file
ref_sheet = 'C:/Users/redinger/Documents/GLANSIS_folder/Endnote_species/Nitellopsis obtusa/Nitellopsis_obtusa_refs_12-12-2023.xlsx'

# Enter scientific and common names (used for keywords)
names = 'Nitellopsis obtusa, starry stonewort'

# %% [markdown]
# ### Create function that finds and removes keywords from PDFs:
# Following function opens first two pages of PDF using PyMuPDF package (fitz.open()). Then finds and prepares keywords to be added to Excel reference sheet.

# %%
# DO NOT EDIT
def keyword_find(filename):
    
    # Open file
    file = fitz.open(filename)
    
    # Read and block only the first two pages of PDF
    text = []
    for i, page in enumerate(file):
        if i > 1:
            break
        text += page.get_text("blocks")
    
    # Close file
    file.close()
    
    # Find block containing keywords - if no keywords in PDF, common & scientific names used
    for block in text:
        if block[4].lower().startswith('key-words:'):
            keywords = block[4][10:].strip()
            break
        elif block[4].lower().startswith('key words:'):
            keywords = block[4][10:].strip()
            break
        elif block[4].lower().startswith('keywords:'):
            keywords = block[4][9:].strip()
            break
        elif block[4].lower().startswith('key-words'):
            keywords = block[4][9:].strip()
            break
        elif block[4].lower().startswith('key words'):
            keywords = block[4][9:].strip()
            break
        elif block[4].lower().startswith('keywords'):
            keywords = block[4][8:].strip()
            break
        else:
            keywords = names
    
    # Clean keywords
    if not keywords == names:
        
        # Remove white space         
        keyword_strip = keywords.strip() 
        
        # Replace intermediate characters - this list is not exhaustive
        keywords_replace = keyword_strip.replace('\n', ', ').replace(' � ', ', ').replace(';', ',').replace('\xa0· , ', ', ').replace('\xa0· ', ', ').replace(' . ', ', ').replace(' / ', ', ').replace(' · ', ', ')
        #keywords_replace = re.sub(r'[\n;�\xa0· /.]', ', ', keyword_strip)
        
        # Combine keywords with scientific and common names
        clean_keywords = str(names) + ', ' + str(keywords_replace)
        
    else:
        clean_keywords = keywords
    
    return(clean_keywords)

# %% [markdown]
# ### Removes duplicates:
# In case combining common and scientific names with keywords creates duplicates, this function will remove and duplicate words

# %%
#DO NOT EDIT

# Removes duplicates
def remove_duplicates_case_insensitive(input_string):
    
    # Create an empty set to keep track of lowercase elements encountered
    lowercased_set = set()
    
    # Create an empty list to store unique elements
    unique_elements = []
    
    # Split the input string
    elements = input_string.split(", ")
    
    # Iterate over each element
    for element in elements:
        
        # Normalize the element
        normalized_element = unicodedata.normalize("NFKD", element) 
        
        # Convert the normalized element to lowercase
        lowercased_element = normalized_element.lower()             
        
        # Check if the lowercase element is not in the set of encountered lowercase elements
        if lowercased_element not in lowercased_set:
            
            # Add the lowercase element to the set
            lowercased_set.add(lowercased_element)
            
            #  Append the original element to unique elements
            unique_elements.append(element)
            
    return ", ".join(unique_elements)

# %% [markdown]
# ### Iterate through file containing PDFs:
# Keywords will be removed from each PDF and added to empty dataframe.

# %%
# DO NOT EDIT

# Create empty dataframe
col_names = ["file.name", "pdf.keywords"]
keywords_df = pd.DataFrame(columns = col_names)

# Pull keywords from each PDF in folder file
for filename in os.listdir(pdfs_folder_path):
    if filename.endswith(".pdf"):
        
        # Create file path
        file_path = os.path.join(pdfs_folder_path, filename)
        
        # Extract keywords
        clean_keywords = keyword_find(file_path)
        
        # Remove duplicates
        unique_keywords = remove_duplicates_case_insensitive(clean_keywords)
        
        # Create a DataFrame row
        row = pd.DataFrame([[filename, unique_keywords]], columns = ["file.name", "pdf.keywords"])
        
        # Concatenate the row DataFrame
        keywords_df = pd.concat([keywords_df, row], ignore_index=True)

# %%
keywords_df
# Out:
#                       file.name  \
# 0           8863-23139-1-PB.pdf
# 1            Boissezon-2018.pdf
# 2           Brzozowski-2018.pdf
# 3           Brzozowski-2021.pdf
# 4                Bučas-2019.pdf
# 5                Bučas-2023.pdf
# 6               Cahill-2020.pdf
# 7               Carver-2022.pdf
# 8           cjfas-2019-0337.pdf
# 9              Escobar-2018.pdf
# 10             Escobar-2019.pdf
# 11                Ginn-2021.pdf
# 12             Glisson-2018.pdf
# 13             Glisson-2020.pdf
# 14             Glisson-2022.pdf
# 15          Gottschalk-2020.pdf
# 16              Gylyte-2021.pdf
# 17               Haram-2023.pdf
# 18         Harrow-Lyle-2020.pdf
# 19         Harrow-Lyle-2021.pdf
# 20         Harrow-Lyle-2022.pdf
# 21         Harrow-Lyle-2023.pdf
# 22         Harrow‐Lyle-2021.pdf
# 23           Hindáková-2022.pdf
# 24               Jurek-2021.pdf
# 25              Khuram-2021.pdf
# 26         Kisnieriene-2019.pdf
# 27            Koselski-2021.pdf
# 28          Lapeikaite-2018.pdf
# 29          Lapeikaitė-2020.pdf
# 30              Larkin-2018.pdf
# 31       Manusadžianas-2020.pdf
# 32            Markovic-2023.pdf
# 33            McCumber-2023.pdf
# 34               Moore-2023.pdf
# 35       Muthukrishnan-2018.pdf
# 36              Neuman-2021.pdf
# 37            Nurashov-2023.pdf
# 38           Pelechaty-2022.pdf
# 39             Pfeifer-2022.pdf
# 40             Pfeifer-2023.pdf
# 41       plants-10-00647-v2.pdf
# 42        Pokrzywinski-2020.pdf
# 43        Pokrzywinski-2022.pdf
# 44              Pupkis-2020.pdf
# 45       s10530-021-02591-8.pdf
# 46             Sanjuan-2018.pdf
# 47        Sinkevičienė-2021.pdf
# 48              Sleith-2018.pdf
# 49              Sleith-2019.pdf
# 50              Sleith-2021.pdf
# 51  sustainability-12-07130.pdf
# 52              Tucker-2022.pdf
# 53              Wagner-2021.pdf
# 54              Wersal-2022.pdf
#
#                                          pdf.keywords
# 0   Nitellopsis obtusa, starry stonewort, aquatic ...
# 1   Nitellopsis obtusa, starry stonewort, , abunda...
# 2   Nitellopsis obtusa, starry stonewort, Bioindic...
# 3   Nitellopsis obtusa, starry stonewort, aquatic ...
# 4   Nitellopsis obtusa, starry stonewort, Macrophy...
# 5   Nitellopsis obtusa, starry stonewort, submerge...
# 6                Nitellopsis obtusa, starry stonewort
# 7                Nitellopsis obtusa, starry stonewort
# 8                Nitellopsis obtusa, starry stonewort
# 9   Nitellopsis obtusa, starry stonewort, Aquatic ...
# 10               Nitellopsis obtusa, starry stonewort
# 11  Nitellopsis obtusa, starry stonewort, Aquatic ...
# 12  Nitellopsis obtusa, starry stonewort, Algaecid...
# 13               Nitellopsis obtusa, starry stonewort
# 14  Nitellopsis obtusa, starry stonewort, Aquatic ...
# 15               Nitellopsis obtusa, starry stonewort
# 16  Nitellopsis obtusa, starry stonewort, Biomarke...
# 17  Nitellopsis obtusa, starry stonewort, Bulbil, ...
# 18               Nitellopsis obtusa, starry stonewort
# 19               Nitellopsis obtusa, starry stonewort
# 20  Nitellopsis obtusa, starry stonewort, Characea...
# 21  Nitellopsis obtusa, starry stonewort, oogonia,...
# 22               Nitellopsis obtusa, starry stonewort
# 23  Nitellopsis obtusa, starry stonewort, Chara, N...
# 24               Nitellopsis obtusa, starry stonewort
# 25  Nitellopsis obtusa, starry stonewort, charophy...
# 26  Nitellopsis obtusa, starry stonewort, Characea...
# 27  Nitellopsis obtusa, starry stonewort, plant ac...
# 28               Nitellopsis obtusa, starry stonewort
# 29               Nitellopsis obtusa, starry stonewort
# 30  Nitellopsis obtusa, starry stonewort, Charophy...
# 31  Nitellopsis obtusa, starry stonewort, Thamnoce...
# 32  Nitellopsis obtusa, starry stonewort, charophy...
# 33  Nitellopsis obtusa, starry stonewort, Invasive...
# 34  Nitellopsis obtusa, starry stonewort, Invasive...
# 35  Nitellopsis obtusa, starry stonewort, Ecologic...
# 36               Nitellopsis obtusa, starry stonewort
# 37  Nitellopsis obtusa, starry stonewort, Characea...
# 38  Nitellopsis obtusa, starry stonewort, Chara-la...
# 39  Nitellopsis obtusa, starry stonewort, arabinog...
# 40               Nitellopsis obtusa, starry stonewort
# 41  Nitellopsis obtusa, starry stonewort, plant ac...
# 42               Nitellopsis obtusa, starry stonewort
# 43               Nitellopsis obtusa, starry stonewort
# 44  Nitellopsis obtusa, starry stonewort, cell sig...
# 45  Nitellopsis obtusa, starry stonewort, Characea...
# 46             Nitellopsis obtusa, starry stonewort,
# 47  Nitellopsis obtusa, starry stonewort, Chara, C...
# 48               Nitellopsis obtusa, starry stonewort
# 49               Nitellopsis obtusa, starry stonewort
# 50  Nitellopsis obtusa, starry stonewort, Characea...
# 51  Nitellopsis obtusa, starry stonewort, Thamnoce...
# 52  Nitellopsis obtusa, starry stonewort, surveill...
# 53               Nitellopsis obtusa, starry stonewort
# 54               Nitellopsis obtusa, starry stonewort

# %% [markdown]
# ### Combine with Excel reference sheet:

# %%
# DO NOT EDIT

# Import reference sheet with blank Keywords column
refs = pd.read_excel(ref_sheet)

# Merge reference file with extract keywords based on name of PDF files
output = refs.merge(keywords_df, how = "left", left_on = "File Attachment", right_on = "file.name")

# Replace original Keywords column and drop new columns
output["Keywords"] = output["pdf.keywords"]
output.drop(["file.name", "pdf.keywords"], axis = 1, inplace = True)

# View output
output.head()
# Out:
#                                               Author  Year  \
# 0           Boissezon, A., D. A. Joye, and T. Garcia  2018
# 1        Carver, P., R. M. Wersal, and B. T. Sartain  2022
# 2  Escobar, L. E., S. Mallez, M. McCartney, C. Le...  2018
# 3  Escobar, L. E., D. Romero-Alvarez, D. J. Larki...  2019
# 4     Ginn, B. K., E. F. S. Dias, and T. Fleischaker  2021
#
#                                                Title  \
# 0  Temporal and spatial changes in population str...
# 1  Small-plot evaluations of aquatic pesticides f...
# 2  Aquatic invasive species in the Great Lakes re...
# 3  Network analysis to inform invasive species sp...
# 4  Trends in submersed aquatic plant communities ...
#
#                                       Journal  Volume  Issue      Pages  \
# 0                              Botany Letters     165    1.0    103-114
# 1         Journal of Aquatic Plant Management      60    NaN      79-84
# 2  Reviews in Fisheries Science & Aquaculture      26    1.0    121-138
# 3         Journal of Oceanology and Limnology      37    3.0  1037-1041
# 4               Lake and Reservoir Management      37    2.0    199-213
#
#                                                  URL  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://www.tandfonline.com/doi/full/10.1080/1...
#
#                              DOI  \
# 0  10.1080/23818107.2017.1356239
# 1                            NaN
# 2  10.1080/23308249.2017.1363715
# 3      10.1007/s00343-019-7208-z
# 4  10.1080/10402381.2020.1859025
#
#                                             Abstract  \
# 0  Nitellopsis obtusa usually inhabits deep lakes...
# 1  Nitellopsis obtusa (Desv.) J. Groves (starry s...
# 2  Aquatic invasive species (AIS) are of concern ...
# 3  Often facilitated by human-mediated pathways, ...
# 4  Ginn BK, Dias EFS, Fleischaker T. 2021. Trends...
#
#                                             Keywords     File Attachment
# 0  Nitellopsis obtusa, starry stonewort, , abunda...  Boissezon-2018.pdf
# 1               Nitellopsis obtusa, starry stonewort     Carver-2022.pdf
# 2  Nitellopsis obtusa, starry stonewort, Aquatic ...    Escobar-2018.pdf
# 3               Nitellopsis obtusa, starry stonewort    Escobar-2019.pdf
# 4  Nitellopsis obtusa, starry stonewort, Aquatic ...       Ginn-2021.pdf

# %% [markdown]
# ### Export excel sheet:

# %%
# Export new file
output.to_excel('C:/Users/redinger/Documents/GLANSIS_folder/Endnote_species/Nitellopsis obtusa/Nitellopsis_obtusa_BulkUpload' + '_' + str(date.today()) + '.xlsx', index = False)

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ycryptodome (c:\users\redinger\appdata\roaming\python\python310\site-packages)
